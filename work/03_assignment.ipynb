# %% [markdown]
# # Linear Regression and Temperature

# %% [markdown]
# In this notebook, we'll look at using linear regression to study changes in temperature.

# %% [markdown]
# ## Setup

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %config InlineBackend.figure_format ='retina'

# %% [markdown]
# ## Getting our data

# %% [markdown]
# We'll be getting data from [North America Land Data Assimilation System (NLDAS)](https://wonder.cdc.gov/NASA-NLDAS.html), which provides the daily average temperature from 1979-2011 for the United States.

# %% [markdown]
# For the next step, you will need to choose some settings in the data request form. These are:
#
# - GroupBy: Month Day, Year
# - Your State
# - Export Results (check box)
# - Show Zero Values (check box)

# %% [markdown]
# >1) Download the data for your home state (or state of your choosing) and upload it to M2 in your work directory.

# %% [markdown]
# # Loading our data

# %%
#df = pd.read_csv('North America Land Data Assimilation System (NLDAS) Daily Air Temperatures and Heat Index (1979-2011).txt',delimiter='\t',skipfooter=14,engine='python')
df = pd.read_csv('../data/North America Land Data Assimilation System (NLDAS) Daily Air Temperatures and Heat Index (1979-2011).txt',delimiter='\t',skipfooter=14,engine='python')

# %%
df
# Out:
#        Notes Month Day, Year Month Day, Year Code  \
# 0        NaN    Jan 01, 1979           1979/01/01
# 1        NaN    Jan 02, 1979           1979/01/02
# 2        NaN    Jan 03, 1979           1979/01/03
# 3        NaN    Jan 04, 1979           1979/01/04
# 4        NaN    Jan 05, 1979           1979/01/05
# ...      ...             ...                  ...
# 12049    NaN    Dec 28, 2011           2011/12/28
# 12050    NaN    Dec 29, 2011           2011/12/29
# 12051    NaN    Dec 30, 2011           2011/12/30
# 12052    NaN    Dec 31, 2011           2011/12/31
# 12053  Total             NaN                  NaN
#
#        Avg Daily Max Air Temperature (F)
# 0                                  29.03
# 1                                  31.35
# 2                                  41.66
# 3                                  47.30
# 4                                  46.89
# ...                                  ...
# 12049                              59.91
# ...

# %% [markdown]
# ### Clean the data

# %% [markdown]
# >2) Drop any rows that have the value "Total" in the Notes column, then drop the Notes column

# %%
df = df.drop(df[df.Notes == 'Total'].index)
df
# Out:
#       Notes Month Day, Year Month Day, Year Code  \
# 0       NaN    Jan 01, 1979           1979/01/01
# 1       NaN    Jan 02, 1979           1979/01/02
# 2       NaN    Jan 03, 1979           1979/01/03
# 3       NaN    Jan 04, 1979           1979/01/04
# 4       NaN    Jan 05, 1979           1979/01/05
# ...     ...             ...                  ...
# 12048   NaN    Dec 27, 2011           2011/12/27
# 12049   NaN    Dec 28, 2011           2011/12/28
# 12050   NaN    Dec 29, 2011           2011/12/29
# 12051   NaN    Dec 30, 2011           2011/12/30
# 12052   NaN    Dec 31, 2011           2011/12/31
#
#        Avg Daily Max Air Temperature (F)
# 0                                  29.03
# 1                                  31.35
# 2                                  41.66
# 3                                  47.30
# 4                                  46.89
# ...                                  ...
# 12048                              56.67
# ...

# %%
del df['Notes']

# %%
df
# Out:
#       Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)
# 0        Jan 01, 1979           1979/01/01                              29.03
# 1        Jan 02, 1979           1979/01/02                              31.35
# 2        Jan 03, 1979           1979/01/03                              41.66
# 3        Jan 04, 1979           1979/01/04                              47.30
# 4        Jan 05, 1979           1979/01/05                              46.89
# ...               ...                  ...                                ...
# 12048    Dec 27, 2011           2011/12/27                              56.67
# 12049    Dec 28, 2011           2011/12/28                              59.91
# 12050    Dec 29, 2011           2011/12/29                              66.64
# 12051    Dec 30, 2011           2011/12/30                              68.61
# 12052    Dec 31, 2011           2011/12/31                              73.49
#
# [12053 rows x 3 columns]

# %% [markdown]
# >3) Make a column called Date that is in the pandas datetime format

# %%
df['Date'] = pd.to_datetime(df['Month Day, Year'])
df
# Out:
#       Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 0        Jan 01, 1979           1979/01/01                              29.03
# 1        Jan 02, 1979           1979/01/02                              31.35
# 2        Jan 03, 1979           1979/01/03                              41.66
# 3        Jan 04, 1979           1979/01/04                              47.30
# 4        Jan 05, 1979           1979/01/05                              46.89
# ...               ...                  ...                                ...
# 12048    Dec 27, 2011           2011/12/27                              56.67
# 12049    Dec 28, 2011           2011/12/28                              59.91
# 12050    Dec 29, 2011           2011/12/29                              66.64
# 12051    Dec 30, 2011           2011/12/30                              68.61
# 12052    Dec 31, 2011           2011/12/31                              73.49
#
#             Date
# ...

# %% [markdown]
# >4) Make columns for 'Year', 'Month', and 'Day' by splitting the column 'Month Day, Year'

# %%
#df.rename(columns={"Month Day, Year": "Month, Day, Year"})
#df
#df["Month", "Day"] = df["Month Day, Year"].str.split(",", expand=True)

# %%
#df[['Month', 'Day', 'Year']] = pd.DataFrame([ x.split() for x in df['Month Day, Year'].tolist() ])
#df['Day']=df['Day'].apply(lambda x:x[1:2])
df['Day'] = df['Date'].apply(lambda d: d.strftime("%d"))
df['Month'] = df['Date'].apply(lambda d: d.strftime("%m"))
df['Year'] = df['Date'].apply(lambda d: d.strftime("%Y"))
df.tail()
# Out:
#       Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 12048    Dec 27, 2011           2011/12/27                              56.67
# 12049    Dec 28, 2011           2011/12/28                              59.91
# 12050    Dec 29, 2011           2011/12/29                              66.64
# 12051    Dec 30, 2011           2011/12/30                              68.61
# 12052    Dec 31, 2011           2011/12/31                              73.49
#
#             Date Day Month  Year
# 12048 2011-12-27  27    12  2011
# 12049 2011-12-28  28    12  2011
# 12050 2011-12-29  29    12  2011
# 12051 2011-12-30  30    12  2011
# 12052 2011-12-31  31    12  2011

# %%
df['DateInt'] = df['Date'].astype(int)/10e10 # This will be used later

# %% [markdown]
# ## Generating a scatter plot

# %% [markdown]
# > 4) Use df.plot.scatter to plot 'Date' vs 'Avg Daily Max Air Temperature (F)'. You might want to add figsize=(50,5) as an argument to make it more clear what is happening.

# %%
#plot = plotdata[['Area_land','Abbreviation']].plot(kind='bar',color='green', figsize=(10,4))
#plot.set_xticklabels(plotdata['Abbreviation'])plot = plotdata[['Area_land','Abbreviation']].plot(kind='bar',color='green', figsize=(10,4))

# %%
df.plot.scatter(x = 'Date', y = 'Avg Daily Max Air Temperature (F)', figsize=(50,5))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Avg Daily Max Air Temperature (F)'>

# %% [markdown]
# >5) Describe your plot.

# %%
#Each u-shape in the figure represents a year (starting with 1979). The section of the graphs with a positive and decreasing slope shows the gradual increase in temperature from the start of the year to summer. The sections with a negative, increasing slope show the decrease in temperature moving towards the winter season. This patterns repeats for each year.

# %% [markdown]
# ### Adding colors for our graph

# %%
# No need to edit this unless you want to try different colors or a pattern other than colors by month

cmap = matplotlib.cm.get_cmap("nipy_spectral", len(df['Month'].unique())) # Builds a discrete color mapping using a built in matplotlib color map

c = []
for i in range(cmap.N): # Converts our discrete map into Hex Values
    rgba = cmap(i)
    c.append(matplotlib.colors.rgb2hex(rgba))

df['color']=[c[int(i-1)] for i in df['Month'].astype(int)] # Adds a column to our dataframe with the color we want for each row

# %% [markdown]
# >6) Make the same plot as 4) but add color by adding the argument c=df\['color'\] to our plotting command.

# %%
df.plot.scatter(x = 'Date', y = 'Avg Daily Max Air Temperature (F)', c=df['color'], figsize=(50,5))
# Out:
# <AxesSubplot:xlabel='Date', ylabel='Avg Daily Max Air Temperature (F)'>

# %% [markdown]
# ## Pick a subset of the data

# %% [markdown]
# >7) Select a 6 month period from the data. # Hint use logic and pd.datetime(YYYY, MM, DD)

# %%
start_date=pd.datetime(2000,1,1)
end_date=pd.datetime(2000,7,1)

# %%
subset=df[(df['Date'] >= start_date) & (df['Date'] < end_date)]
subset
# Out:
#      Month Day, Year Month Day, Year Code  Avg Daily Max Air Temperature (F)  \
# 7670    Jan 01, 2000           2000/01/01                              75.12
# 7671    Jan 02, 2000           2000/01/02                              72.87
# 7672    Jan 03, 2000           2000/01/03                              61.42
# 7673    Jan 04, 2000           2000/01/04                              50.62
# 7674    Jan 05, 2000           2000/01/05                              57.84
# ...              ...                  ...                                ...
# 7847    Jun 26, 2000           2000/06/26                              91.59
# 7848    Jun 27, 2000           2000/06/27                              88.92
# 7849    Jun 28, 2000           2000/06/28                              90.62
# 7850    Jun 29, 2000           2000/06/29                              88.07
# 7851    Jun 30, 2000           2000/06/30                              91.74
#
# ...

# %% [markdown]
# >8) Plot the subset using the the same code you used in 6). You can change the figsize if needed.

# %%
cmap = matplotlib.cm.get_cmap("nipy_spectral", len(subset['Month'].unique())) # Builds a discrete color mapping using a built in matplotlib color map

c = []
for i in range(cmap.N): # Converts our discrete map into Hex Values
    rgba = cmap(i)
    c.append(matplotlib.colors.rgb2hex(rgba))

subset['color']=[c[int(i-1)] for i in subset['Month'].astype(int)] # Adds a column to our dataframe with the color we want for each row
subset.plot.scatter(x = 'Date', y = 'Avg Daily Max Air Temperature (F)', c=subset['color'], figsize=(5,5))
# Out:
# /tmp/ipykernel_2450602/3589191297.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['color']=[c[int(i-1)] for i in subset['Month'].astype(int)] # Adds a column to our dataframe with the color we want for each row
# <AxesSubplot:xlabel='Date', ylabel='Avg Daily Max Air Temperature (F)'>

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# We are going to use a very [simple linear regression model](https://en.wikipedia.org/wiki/Simple_linear_regression). You may implement a more complex model if you wish.
#
# The method described here is called the least squares method and is defined as:
#
# $m = \frac{\sum_{i=1}^{n}(x_i-\bar{x})(y_i-\bar{y}))}{\sum_{i=1}^{n}(x_i-\bar{x})^2}$
#
# $b = \bar{y} - m\bar{x}$
#
# Where $\bar{x}$ and $\bar{y}$ are the average value of $x$ and $y$ respectively.

# %% [markdown]
# First we need to define our X and Y values.

# %%
X=subset['DateInt'].values
Y=subset['Avg Daily Max Air Temperature (F)'].values

# %%
def lin_reg(x,y):
    # Calculate the average x and y
    x_avg = np.mean(x)
    y_avg = np.mean(y)

    num = 0
    den = 0
    for i in range(len(x)): # This represents our sums
        num = num + (x[i] - x_avg)*(y[i] - y_avg) # Our numerator
        den = den + (x[i] - x_avg)**2 # Our denominator
    # Calculate slope
    m = num / den
    # Calculate intercept
    b = y_avg - m*x_avg

    print (m, b)
    
    # Calculate our predicted y values
    y_pred = m*x + b
    
    return y_pred

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 0.0002198042956918965 -2019.6018934520785

# %%
subset.plot.scatter(x='Date', y='Avg Daily Max Air Temperature (F)',c=subset['color'])
plt.plot([min(subset['Date'].values), max(subset['Date'].values)], [min(Y_pred), max(Y_pred)], color='red') # best fit line
plt.show()

# %% [markdown]
# >9) What are the slope and intercept of your best fit line?

# %%
#slope= 0.0002198042956918965 
#intercept= -2019.6018934520785

# %% [markdown]
# >10) What are the minimum and maximum Y values of your best fit line? Is your slope positive or negative?

# %%
Y_pred.min()
# Out:
# 61.2519636101606

# %%
Y_pred.max()
# Out:
# 95.62583858764219

# %%
#Slope is positive

# %% [markdown]
# ## Putting it all together

# %% [markdown]
# >11) Generate a best fit line for the full data set and plot the line over top of the data.

# %%
X=df['DateInt'].values
Y=df['Avg Daily Max Air Temperature (F)'].values

# %%
Y_pred = lin_reg(X,Y)
# Out:
# 3.072410840971274e-07 75.67019246681011

# %%
df.plot.scatter(x='Date', y='Avg Daily Max Air Temperature (F)',c=df['color'])
plt.plot([min(df['Date'].values), max(df['Date'].values)], [min(Y_pred), max(Y_pred)], color='red') # best fit line
plt.show()

# %% [markdown]
# >12) Is the slope positive or negative? What do you think that means?

# %%
#Positive- Gradual increase in average daily temperature each year due to climate change.
